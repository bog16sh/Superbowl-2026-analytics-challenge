# %%
import polars as pl

# Load the entire tags.csv file
df = pl.read_csv("tags.csv")


# Keep only the first occurrence of each unique id
df_unique = df.unique(subset="id", keep="first")
df_unique
# Out:
# shape: (46_257, 34)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ id        ┆ possibly_ ┆ text      ┆ author_id ┆ … ┆ location  ┆ brand     ┆ withheld. ┆ attachme │
# │ ---       ┆ sensitive ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ country_c ┆ nts.poll │
# │ i64       ┆ ---       ┆ str       ┆ i64       ┆   ┆ str       ┆ str       ┆ odes      ┆ _ids     │
# │           ┆ bool      ┆           ┆           ┆   ┆           ┆           ┆ ---       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ str       ┆ str      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 202069783 ┆ false     ┆ RT @Aaisa ┆ 158890542 ┆ … ┆ null      ┆ Wix.com_1 ┆ ['ID']    ┆ null     │
# │ 325571504 ┆           ┆ M1x:      ┆ 329738444 ┆   ┆           ┆           ┆           ┆          │
# ...
